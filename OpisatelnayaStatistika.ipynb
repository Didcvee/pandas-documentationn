# %%
import matplotlib.pyplot as plt

# %%
# подготовим наши данные

# во-первых, возьмем список курсов
year = ['Первый', 'Второй', 'Третий', 'Четвертый', 'Пятый']
# во-вторых, количество студентов на каждом из них
frequency = [500, 470, 300, 260, 220]

# воспользуемся функцией bar и передадим ей два списка в качестве аргументов
plt.bar(year, frequency)

# создадим заголовок и подписи к осям, здесь ничего нового
plt.xlabel('Курс')
plt.ylabel('Количество студентов')
plt.title('Распределение студентов по курсам университета')
# Out:
# Text(0.5, 1.0, 'Распределение студентов по курсам университета')

# %%
# !wget https://raw.githubusercontent.com/h4pZ/rose-pine-matplotlib/main/themes/rose-pine.mplstyle -P /tmp
# !wget https://raw.githubusercontent.com/h4pZ/rose-pine-matplotlib/main/themes/rose-pine-dawn.mplstyle -P /tmp
# !wget https://raw.githubusercontent.com/h4pZ/rose-pine-matplotlib/main/themes/rose-pine-moon.mplstyle -P /tmp
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# %matplotlib inline
import requests

url = "https://raw.githubusercontent.com/h4pZ/rose-pine-matplotlib/main/themes/rose-pine-dawn.mplstyle"
response = requests.get(url)
with open('/tmp/rose-pine-dawn.mplstyle', 'wb') as file:
    file.write(response.content)
url = "https://raw.githubusercontent.com/h4pZ/rose-pine-matplotlib/main/themes/rose-pine-moon.mplstyle"
response = requests.get(url)
with open('/tmp/rose-pine-moon.mplstyle', 'wb') as file:
    file.write(response.content)

# %%
len(plt.style.available)
# Out:
# 28

# %%
with plt.style.context('/tmp/rose-pine-moon.mplstyle'):
    year = ['Первый', 'Второй', 'Третий', 'Четвертый', 'Пятый']
    # во-вторых, количество студентов на каждом из них
    frequency = [500, 470, 300, 260, 220]

    # воспользуемся функцией bar и передадим ей два списка в качестве аргументов
    plt.bar(year, frequency)

    # создадим заголовок и подписи к осям, здесь ничего нового
    plt.xlabel('Курс')
    plt.ylabel('Количество студентов')
    plt.title('Распределение студентов по курсам университета')

# %%
with plt.style.context('stylename'):
    plt.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\__init__.py:894, in _rc_params_in_file(fname, transform, fail_on_error)
#     893 rc_temp = {}
# --> 894 with _open_file_or_url(fname) as fd:
#     895     try:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\__init__.py:871, in _open_file_or_url(fname)
#     870 fname = os.path.expanduser(fname)
# --> 871 with open(fname, encoding='utf-8') as f:
#     872     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stylename'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 with plt.style.context('stylename'):
#       2     plt.plot()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\style\core.py:194, in context(style, after_reset)
#     192 if after_reset:
#     193     mpl.rcdefaults()
# --> 194 use(style)
#     195 yield
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\style\core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'stylename' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
