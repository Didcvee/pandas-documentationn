# %%
import pandas as pd

# %%
bank_db = {
    'Name' : ['Иван Иванович', 'Иван Петрович'],
    'Age' : [0, 1],
    'Experience' : [4, 7],
    'Salary' : [75, 95],
    'Credit_score' : [4, 8],
    'Outcome' : [0, 1]
}

# %%
df = pd.DataFrame(bank_db)

# %%
print(df)
# Out:
#             Name  Age  Experience  Salary  Credit_score  Outcome
# 0  Иван Иванович    0           4      75             4        0
# 1  Иван Петрович    1           7      95             8        1

# %%
df['Salary'].mean() # среднее
# Out:
# 85.0

# %%
import matplotlib.pyplot as plt

# %%
# передаем функции plot() библиотеки Matplotlib два значения: доход и уровень счастья
plt.plot([70, 80, 100, 150, 300], [1, 4, 6, 9, 16])

plt.style.use("fivethirtyeight")

# добавим подписи для наглядности
plt.xlabel('Доход, тыс. рублей') # для оси x
plt.ylabel('Счастье, вымышленные единицы') # для оси y
plt.title('Счастье и уровень дохода') # заголовок

plt.show() # посмотрим, что у нас получилось

# %%
import numpy as np
from scipy.special import jv
import matplotlib.pyplot as plt

plt.style.use("fivethirtyeight")

fig, ax = plt.subplots()
x = np.linspace(-10, 10, 100)

for i in range(0, 3):
  J = jv(i, x)
  ax.plot(x, J)

# %%
# подготовим наши данные

# во-первых, возьмем список курсов
year = ['Первый', 'Второй', 'Третий', 'Четвертый', 'Пятый']
# во-вторых, количество студентов на каждом из них
frequency = [500, 470, 300, 260, 220]
# воспользуемся функцией bar и передадим ей два списка в качестве аргументов
plt.bar(year, frequency)

plt.style.use("Solarize_Light2")

# создадим заголовок и подписи к осям, здесь ничего нового
plt.xlabel('Курс')
plt.ylabel('Количество студентов')
plt.title('Распределение студентов по курсам университета')
# Out:
# Text(0.5, 1.0, 'Распределение студентов по курсам университета')

# %%
# use a gray background
ax = plt.axes(axisbg='#E6E6E6')
ax.set_axisbelow(True)

# draw solid white grid lines
plt.grid(color='w', linestyle='solid')

# hide axis spines
for spine in ax.spines.values():
    spine.set_visible(False)
    
# hide top and right ticks
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

# lighten ticks and labels
ax.tick_params(colors='gray', direction='out')
for tick in ax.get_xticklabels():
    tick.set_color('gray')
for tick in ax.get_yticklabels():
    tick.set_color('gray')
    
# control face and edge color of histogram
ax.hist(x, edgecolor='#E6E6E6', color='#EE6666');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # use a gray background
# ----> 2 ax = plt.axes(axisbg='#E6E6E6')
#       3 ax.set_axisbelow(True)
#       5 # draw solid white grid lines
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\pyplot.py:1236, in axes(arg, **kwargs)
#    1234 if arg is None:
#    1235     if pos is None:
# -> 1236         return fig.add_subplot(**kwargs)
#    1237     else:
#    1238         return fig.add_axes(pos, **kwargs)
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\figure.py:782, in FigureBase.add_subplot(self, *args, **kwargs)
#     780         args = tuple(map(int, str(args[0])))
#     781     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 782     ax = projection_class(self, *args, **pkw)
#     783     key = (projection_class, pkw)
#     784 return self._add_axes_internal(ax, key)
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\axes\_base.py:692, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     689 if yscale:
#     690     self.set_yscale(yscale)
# --> 692 self._internal_update(kwargs)
#     694 for name, axis in self._axis_map.items():
#     695     axis.callbacks._connect_picklable(
#     696         'units', self._unit_change_handler(name))
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~\PycharmProjects\pythonProject1\venv\lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Axes.set() got an unexpected keyword argument 'axisbg'

# %%
from matplotlib import cycler
colors = cycler('color',
                ['#EE6666', '#3388BB', '#9988DD',
                 '#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %%
plt.hist(x);

# %%
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a', 'b', 'c'], loc='lower left')

# %%
with plt.style.context('ggplot'):
    hist_and_lines()
